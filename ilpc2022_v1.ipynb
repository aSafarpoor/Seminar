# %% [markdown]
# <a href="https://colab.research.google.com/github/aSafarpoor/Seminar/blob/main/ilpc2022_v1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd drive/MyDrive/MSc/codes/ilpc2022/
# Out:
# /content/drive/MyDrive/MSc/codes/ilpc2022

# %%
# !pip install pykeen
# !pip install click
# !pip install wandb
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pykeen
#   Downloading pykeen-1.8.1-py3-none-any.whl (630 kB)
#      |████████████████████████████████| 630 kB 7.4 MB/s
# Requirement already satisfied: tabulate in /usr/local/lib/python3.7/dist-packages (from pykeen) (0.8.9)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from pykeen) (4.64.0)
# Requirement already satisfied: pandas>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from pykeen) (1.3.5)
# Requirement already satisfied: sklearn in /usr/local/lib/python3.7/dist-packages (from pykeen) (0.0)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.7/dist-packages (from pykeen) (8.13.0)
# Requirement already satisfied: torch>=1.10 in /usr/local/lib/python3.7/dist-packages (from pykeen) (1.11.0+cu113)
# Collecting scipy>=1.5.0
#   Downloading scipy-1.7.3-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (38.1 MB)
#      |████████████████████████████████| 38.1 MB 382 kB/s
# Collecting rexmex
#   Downloading rexmex-0.1.0.tar.gz (21 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#     Preparing wheel metadata ... done
# Collecting click-default-group
#   Downloading click-default-group-1.2.2.tar.gz (3.3 kB)
# Collecting optuna>=2.0.0
#   Downloading optuna-2.10.0-py3-none-any.whl (308 kB)
#      |████████████████████████████████| 308 kB 68.9 MB/s
# Collecting docdata
#   Downloading docdata-0.0.3-py3-none-any.whl (5.8 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from pykeen) (2.23.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from pykeen) (1.21.6)
# Collecting pystow>=0.1.5
#   Downloading pystow-0.4.3-py3-none-any.whl (33 kB)
# Collecting more-click
#   Downloading more_click-0.1.1-py3-none-any.whl (6.2 kB)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from pykeen) (3.13)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from pykeen) (7.1.2)
# Collecting class-resolver>=0.3.9
#   Downloading class_resolver-0.3.9-py3-none-any.whl (21 kB)
# Collecting dataclasses-json
#   Downloading dataclasses_json-0.5.7-py3-none-any.whl (25 kB)
# Collecting colorlog
#   Downloading colorlog-6.6.0-py2.py3-none-any.whl (11 kB)
# Collecting cliff
#   Downloading cliff-3.10.1-py3-none-any.whl (81 kB)
#      |████████████████████████████████| 81 kB 12.1 MB/s
# Requirement already satisfied: sqlalchemy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from optuna>=2.0.0->pykeen) (1.4.36)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from optuna>=2.0.0->pykeen) (21.3)
# Collecting cmaes>=0.8.2
#   Downloading cmaes-0.8.2-py3-none-any.whl (15 kB)
# Collecting alembic
#   Downloading alembic-1.7.7-py3-none-any.whl (210 kB)
#      |████████████████████████████████| 210 kB 77.6 MB/s
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->optuna>=2.0.0->pykeen) (3.0.9)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.0.0->pykeen) (2022.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.0.0->pykeen) (2.8.2)
# Collecting pickle5
#   Downloading pickle5-0.0.12-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (256 kB)
#      |████████████████████████████████| 256 kB 64.5 MB/s
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=1.0.0->pykeen) (1.15.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.7/dist-packages (from sqlalchemy>=1.1.0->optuna>=2.0.0->pykeen) (1.1.2)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from sqlalchemy>=1.1.0->optuna>=2.0.0->pykeen) (4.11.3)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.10->pykeen) (4.2.0)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.7/dist-packages (from alembic->optuna>=2.0.0->pykeen) (5.7.1)
# Collecting Mako
#   Downloading Mako-1.2.0-py3-none-any.whl (78 kB)
#      |████████████████████████████████| 78 kB 9.6 MB/s
# Collecting pbr!=2.1.0,>=2.0.0
#   Downloading pbr-5.9.0-py2.py3-none-any.whl (112 kB)
#      |████████████████████████████████| 112 kB 57.5 MB/s
# Collecting stevedore>=2.0.1
#   Downloading stevedore-3.5.0-py3-none-any.whl (49 kB)
#      |████████████████████████████████| 49 kB 8.8 MB/s
# Requirement already satisfied: PrettyTable>=0.7.2 in /usr/local/lib/python3.7/dist-packages (from cliff->optuna>=2.0.0->pykeen) (3.3.0)
# Collecting cmd2>=1.0.0
#   Downloading cmd2-2.4.1-py3-none-any.whl (146 kB)
#      |████████████████████████████████| 146 kB 72.5 MB/s
# Collecting autopage>=0.4.0
#   Downloading autopage-0.5.0-py3-none-any.whl (29 kB)
# Requirement already satisfied: wcwidth>=0.1.7 in /usr/local/lib/python3.7/dist-packages (from cmd2>=1.0.0->cliff->optuna>=2.0.0->pykeen) (0.2.5)
# Collecting pyperclip>=1.6
#   Downloading pyperclip-1.8.2.tar.gz (20 kB)
# Requirement already satisfied: attrs>=16.3.0 in /usr/local/lib/python3.7/dist-packages (from cmd2>=1.0.0->cliff->optuna>=2.0.0->pykeen) (21.4.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->sqlalchemy>=1.1.0->optuna>=2.0.0->pykeen) (3.8.0)
# Collecting typing-inspect>=0.4.0
#   Downloading typing_inspect-0.7.1-py3-none-any.whl (8.4 kB)
# Collecting marshmallow-enum<2.0.0,>=1.5.1
#   Downloading marshmallow_enum-1.5.1-py2.py3-none-any.whl (4.2 kB)
# Collecting marshmallow<4.0.0,>=3.3.0
#   Downloading marshmallow-3.15.0-py3-none-any.whl (47 kB)
#      |████████████████████████████████| 47 kB 5.1 MB/s
# Collecting mypy-extensions>=0.3.0
#   Downloading mypy_extensions-0.4.3-py2.py3-none-any.whl (4.5 kB)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.7/dist-packages (from Mako->alembic->optuna>=2.0.0->pykeen) (2.0.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->pykeen) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->pykeen) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->pykeen) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->pykeen) (2022.5.18.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from rexmex->pykeen) (1.0.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->rexmex->pykeen) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->rexmex->pykeen) (1.1.0)
# Building wheels for collected packages: click-default-group, pyperclip, rexmex
#   Building wheel for click-default-group (setup.py) ... done
#   Created wheel for click-default-group: filename=click_default_group-1.2.2-py3-none-any.whl size=3385 sha256=dea5a6dabf1d92bf3f7648f8688091013364073ab998d96406e58b0046025d5f
#   Stored in directory: /root/.cache/pip/wheels/c8/01/63/03a469931aa81497b07ada86ff8aa1b18847bdbe474f43d82c
#   Building wheel for pyperclip (setup.py) ... done
#   Created wheel for pyperclip: filename=pyperclip-1.8.2-py3-none-any.whl size=11137 sha256=27abc2b2d857a79cfa04897ed2f97c863f79cf1a17086afe07690e6d9694bd9e
#   Stored in directory: /root/.cache/pip/wheels/9f/18/84/8f69f8b08169c7bae2dde6bd7daf0c19fca8c8e500ee620a28
#   Building wheel for rexmex (PEP 517) ... done
#   Created wheel for rexmex: filename=rexmex-0.1.0-py3-none-any.whl size=19981 sha256=f6a107ea241bc26403f1b44ffa9e94fa805e21a36437c19771aabc7aad87273c
#   Stored in directory: /root/.cache/pip/wheels/94/25/13/89fb82f45c6fbbac6491ff53b8705b8944bf77bbb4e4be1f2d
# Successfully built click-default-group pyperclip rexmex
# Installing collected packages: scipy, pyperclip, pbr, stevedore, mypy-extensions, marshmallow, Mako, cmd2, autopage, typing-inspect, pickle5, marshmallow-enum, colorlog, cmaes, cliff, alembic, rexmex, pystow, optuna, more-click, docdata, dataclasses-json, click-default-group, class-resolver, pykeen
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.4.1
#     Uninstalling scipy-1.4.1:
#       Successfully uninstalled scipy-1.4.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# Successfully installed Mako-1.2.0 alembic-1.7.7 autopage-0.5.0 class-resolver-0.3.9 click-default-group-1.2.2 cliff-3.10.1 cmaes-0.8.2 cmd2-2.4.1 colorlog-6.6.0 dataclasses-json-0.5.7 docdata-0.0.3 marshmallow-3.15.0 marshmallow-enum-1.5.1 more-click-0.1.1 mypy-extensions-0.4.3 optuna-2.10.0 pbr-5.9.0 pickle5-0.0.12 pykeen-1.8.1 pyperclip-1.8.2 pystow-0.4.3 rexmex-0.1.0 scipy-1.7.3 stevedore-3.5.0 typing-inspect-0.7.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting wandb
#   Downloading wandb-0.12.16-py2.py3-none-any.whl (1.8 MB)
#      |████████████████████████████████| 1.8 MB 9.3 MB/s
# Requirement already satisfied: Click!=8.0.0,>=7.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (7.1.2)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (5.4.8)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.7/dist-packages (from wandb) (2.8.2)
# Collecting GitPython>=1.0.0
#   Downloading GitPython-3.1.27-py3-none-any.whl (181 kB)
#      |████████████████████████████████| 181 kB 75.6 MB/s
# Requirement already satisfied: promise<3,>=2.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (2.3)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.7/dist-packages (from wandb) (3.13)
# Requirement already satisfied: protobuf>=3.12.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (3.17.3)
# Collecting setproctitle
#   Downloading setproctitle-1.2.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (29 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from wandb) (57.4.0)
# Collecting docker-pycreds>=0.4.0
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Collecting shortuuid>=0.5.0
#   Downloading shortuuid-1.0.9-py3-none-any.whl (9.4 kB)
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (2.23.0)
# Collecting sentry-sdk>=1.0.0
#   Downloading sentry_sdk-1.5.12-py2.py3-none-any.whl (145 kB)
#      |████████████████████████████████| 145 kB 76.9 MB/s
# Collecting pathtools
#   Downloading pathtools-0.1.2.tar.gz (11 kB)
# Requirement already satisfied: six>=1.13.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (1.15.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from GitPython>=1.0.0->wandb) (4.2.0)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.9-py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 2.3 MB/s
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (2022.5.18.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (3.0.4)
# Building wheels for collected packages: pathtools
#   Building wheel for pathtools (setup.py) ... done
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8806 sha256=851d650117563ea86cbdfdab00f5a87973d8d39777b2afca5f4710a4355e3a78
#   Stored in directory: /root/.cache/pip/wheels/3e/31/09/fa59cef12cdcfecc627b3d24273699f390e71828921b2cbba2
# Successfully built pathtools
# Installing collected packages: smmap, gitdb, shortuuid, setproctitle, sentry-sdk, pathtools, GitPython, docker-pycreds, wandb
# Successfully installed GitPython-3.1.27 docker-pycreds-0.4.0 gitdb-4.0.9 pathtools-0.1.2 sentry-sdk-1.5.12 setproctitle-1.2.3 shortuuid-1.0.9 smmap-5.0.0 wandb-0.12.16

# %%
import datetime

# %%
"""The challenge's datasets."""
from pathlib import Path

from pykeen.datasets.inductive.base import DisjointInductivePathDataset
from typing_extensions import Literal

__all__ = [
    "InductiveLPDataset",
    "Size",
]

# HERE = Path(__file__).parent.resolve()
DATA = "data/"

Size = Literal["small/", "large/", "sp/"]


class InductiveLPDataset(DisjointInductivePathDataset):
    """An inductive link prediction dataset for the ILPC 2022 Challenge."""

    def __init__(self, size= "small/", **kwargs):
        """Initialize the inductive link prediction dataset.

        :param size: "small" or "large"
        :param kwargs: keyword arguments to forward to the base dataset class, cf. DisjointInductivePathDataset
        """

        super().__init__(
            transductive_training_path=size+ "train.txt",
            inductive_inference_path=size+ "inference.txt",
            inductive_validation_path=size+ "inference_validation.txt",
            inductive_testing_path=size+ "inference_test.txt",
            create_inverse_triples=True,
            eager=True,
            **kwargs
        )

# %%
"""Example workflow."""
import logging
from pathlib import Path

# import click
# import more_click
import torch
from pykeen.evaluation import RankBasedEvaluator
from pykeen.losses import NSSALoss
from pykeen.models.inductive import InductiveNodePiece, InductiveNodePieceGNN
from pykeen.trackers import ConsoleResultTracker, WANDBResultTracker
from pykeen.training import SLCWATrainingLoop
from pykeen.typing import TESTING, TRAINING, VALIDATION
from pykeen.utils import resolve_device, set_random_seed
from torch.optim import Adam


DATA = "data/"

# fix the seed for reproducibility
set_random_seed(42)


# for GNN layer reproducibility
# when running on a GPU, make sure to set up an env variable as advised in the doc:
# https://pytorch.org/docs/stable/generated/torch.use_deterministic_algorithms.html

# torch.use_deterministic_algorithms(True)

'''
click.Choice(["small", "large","sp"]),
default="small",
    show_default=True,
    help="The dataset to use",
)

    "--embedding-dim",
    help="The dimension of the entity embeddings",

    "--tokens",
    help="Number of tokens to use in NodePiece",

    "--margin",
    help="The margin value to use for the negative sampling self-adversarial loss.",

    "--num-negatives",
    help="The number of negative samples per positive.",

    "--wandb",
    help="Track results with Weights & Biases (requires `wandb` to be installed).",

    "--save",
     is_flag=True, help=f"Save the model in the {DATA} directory")

    "--gnn", 
    is_flag=True, help="Use the Inductive NodePiece model with GCN layers"

@more_click.log_level_option()
'''


def main(
    dataset= 'sp/',
    embedding_dim= 100,
    tokens= 5,
    learning_rate= 0.001,
    margin= 15.0,
    num_negatives= 4,
    batch_size= 256,
    epochs= 2,
    wandb= True,
    save= True,
    gnn= True,
    log_level= ""):


    """Train an inductive model with NodePiece representations and an optional GNN encoder."""
    # set appropriate log-level
    logging.basicConfig(level=log_level)

    # dataset loading
    dataset = InductiveLPDataset(size=dataset)
    loss = NSSALoss(margin=margin)

    # we have two baselines: InductiveNodePiece and InductiveNodePieceGNN
    # the GNN version uses a 2-layer CompGCN message passing encoder on the training / inference graphs
    # but feel free to create and attach your own GNN encoder via the gnn_encoder argument
    # and new inductive link prediction models in general
    model_cls = InductiveNodePieceGNN if gnn else InductiveNodePiece
    model = model_cls(
        embedding_dim=embedding_dim,
        triples_factory=dataset.transductive_training,
        inference_factory=dataset.inductive_inference,
        num_tokens=tokens,
        aggregation="mlp",
        loss=loss,
    ).to(resolve_device())
    optimizer = Adam(params=model.parameters(), lr=learning_rate)
    logging.info(f"Number of parameters: {sum(p.numel() for p in model.parameters())}")
    logging.info(f"Space occupied: {model.num_parameter_bytes} bytes")

    if wandb:
        tracker = WANDBResultTracker(
            project="inductive_ilp",  # put here your project and entity
            entity="pykeen",
            # config=click.get_current_context().params,
        )
        tracker.start_run()
    else:
        tracker = ConsoleResultTracker()

    # default training regime is negative sampling (SLCWA)
    # you can also use the 1-N regime with the LCWATrainingLoop
    # the LCWA loop does not need negative sampling kwargs, but accepts label_smoothing in the .train() method
    training_loop = SLCWATrainingLoop(
        triples_factory=dataset.transductive_training,
        model=model,
        optimizer=optimizer,
        result_tracker=tracker,
        negative_sampler_kwargs=dict(
            # affects training speed, the more - the better
            num_negs_per_pos=num_negatives
        ),
        mode=TRAINING,  # must be specified for the inductive setup
    )

    # specifying hits@k values: 1, 3, 5, 10, 100
    valid_evaluator = RankBasedEvaluator(
        mode=VALIDATION,
        metrics=["hits_at_k"]*5,
        metrics_kwargs=[dict(k=k) for k in (1, 3, 5, 10, 100)],
        add_defaults=True,
    )
    test_evaluator = RankBasedEvaluator(
        mode=TESTING,
        metrics=["hits_at_k"] * 5,
        metrics_kwargs=[dict(k=k) for k in (1, 3, 5, 10, 100)],
        add_defaults=True
    )

    # model training and eval on validation starts here
    training_loop.train(
        triples_factory=dataset.transductive_training,
        num_epochs=epochs,
        batch_size=batch_size,
        callbacks="evaluation",
        callback_kwargs=dict(
            evaluator=valid_evaluator,
            evaluation_triples=dataset.inductive_validation.mapped_triples,
            prefix="validation",
            frequency=1,
            additional_filter_triples=dataset.inductive_inference.mapped_triples,
            batch_size=batch_size,
        ),
    )

    # final eval on the test set
    result = test_evaluator.evaluate(
        model=model,
        mapped_triples=dataset.inductive_testing.mapped_triples,
        additional_filter_triples=[
            # filtering of other positive triples
            dataset.inductive_inference.mapped_triples,
            dataset.inductive_validation.mapped_triples,
        ],
        batch_size=batch_size,
    )

    # extracting final metrics
    for metric, metric_label in [
        ("inverse_harmonic_mean_rank", "MRR"),
        *((f"hits_at_{k}", f"Hits@{k}") for k in (100, 10, 3, 1)),
        ("adjusted_arithmetic_mean_rank_index", "AMRI"),
    ]:
        logging.info(f"Test {metric_label:10}: {result.get_metric(name=metric):.5f}")

    # you can also log the final results to wandb if you want
    if wandb:
        tracker.log_metrics(
            metrics=result.to_flat_dict(),
            step=epochs + 1,
            prefix="test",
        )

    # saving the final model
    if save:
        current_time = datetime.datetime.now() 
        s = current_time.isoformat()
        print(s)
        torch.save(model, "result/model_"+s)

# %%
main(dataset= 'data/small/',
    embedding_dim= 100,
    tokens= 5,
    learning_rate= 0.001,
    margin= 15.0,
    num_negatives= 4,
    batch_size= 256,
    epochs= 50,
    wandb= False,
    save= True,
    gnn= True,
    log_level= "Trace"
    )
# Out:
# WARNING:pykeen.models.base:No random seed is specified. This may lead to non-reproducible results.
# sampling:   0%|          | 0.00/10.2k [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/pykeen/nn/representation.py:372: UserWarning: Directly use Embedding.max_id instead of num_embeddings.
#   warnings.warn(f"Directly use {self.__class__.__name__}.max_id instead of num_embeddings.")
# sampling:   0%|          | 0.00/6.65k [00:00<?, ?it/s]
# INFO:pykeen.triples.triples_factory:Creating inverse triples.
# Training epochs on cuda:0:   0%|          | 0/50 [00:00<?, ?epoch/s]
# INFO:pykeen.triples.triples_factory:Creating inverse triples.
# INFO:pykeen.training.training_loop:Dropping last (incomplete) batch each epoch (1/614 (0.16%) batches).
# Training batches on cuda:0:   0%|          | 0/614 [00:00<?, ?batch/s]
# Evaluating on cuda:0:   0%|          | 0.00/2.91k [00:00<?, ?triple/s]
# INFO:pykeen.evaluation.evaluator:Evaluation took 0.57s seconds
# Step: 1
# Metric: validation.head.optimistic.hits_at_1 = 0.004470426409903714
# Metric: validation.tail.optimistic.hits_at_1 = 0.007909215955983494
# Metric: validation.both.optimistic.hits_at_1 = 0.006189821182943604
# Metric: validation.head.realistic.hits_at_1 = 0.004470426409903714
# Metric: validation.tail.realistic.hits_at_1 = 0.007909215955983494
# Metric: validation.both.realistic.hits_at_1 = 0.006189821182943604
# Metric: validation.head.pessimistic.hits_at_1 = 0.004470426409903714
# Metric: validation.tail.pessimistic.hits_at_1 = 0.007909215955983494
# Metric: validation.both.pessimistic.hits_at_1 = 0.006189821182943604
# Metric: validation.head.optimistic.hits_at_3 = 0.013067400275103164
# Metric: validation.tail.optimistic.hits_at_3 = 0.03163686382393398
# Metric: validation.both.optimistic.hits_at_3 = 0.02235213204951857
# Metric: validation.head.realistic.hits_at_3 = 0.013067400275103164
# Metric: validation.tail.realistic.hits_at_3 = 0.03163686382393398
# Metric: validation.both.realistic.hits_at_3 = 0.02235213204951857
# Metric: validation.head.pessimistic.hits_at_3 = 0.013067400275103164
# Metric: validation.tail.pessimistic.hits_at_3 = 0.03163686382393398
# Metric: validation.both.pessimistic.hits_at_3 = 0.02235213204951857
# Metric: validation.head.optimistic.hits_at_5 = 0.01891334250343879
# Metric: validation.tail.optimistic.hits_at_5 = 0.05055020632737277
# Metric: validation.both.optimistic.hits_at_5 = 0.03473177441540578
# Metric: validation.head.realistic.hits_at_5 = 0.01891334250343879
# Metric: validation.tail.realistic.hits_at_5 = 0.05055020632737277
# Metric: validation.both.realistic.hits_at_5 = 0.03473177441540578
# Metric: validation.head.pessimistic.hits_at_5 = 0.01891334250343879
# Metric: validation.tail.pessimistic.hits_at_5 = 0.05055020632737277
# Metric: validation.both.pessimistic.hits_at_5 = 0.03473177441540578
# Metric: validation.head.optimistic.hits_at_10 = 0.030261348005502064
# Metric: validation.tail.optimistic.hits_at_10 = 0.08321870701513068
# Metric: validation.both.optimistic.hits_at_10 = 0.05674002751031637
# Metric: validation.head.realistic.hits_at_10 = 0.030261348005502064
# Metric: validation.tail.realistic.hits_at_10 = 0.08321870701513068
# Metric: validation.both.realistic.hits_at_10 = 0.05674002751031637
# Metric: validation.head.pessimistic.hits_at_10 = 0.030261348005502064
# Metric: validation.tail.pessimistic.hits_at_10 = 0.08321870701513068
# Metric: validation.both.pessimistic.hits_at_10 = 0.05674002751031637
# Metric: validation.head.optimistic.hits_at_100 = 0.10866574965612105
# Metric: validation.tail.optimistic.hits_at_100 = 0.2843878954607978
# Metric: validation.both.optimistic.hits_at_100 = 0.19652682255845944
# Metric: validation.head.realistic.hits_at_100 = 0.10866574965612105
# Metric: validation.tail.realistic.hits_at_100 = 0.2843878954607978
# Metric: validation.both.realistic.hits_at_100 = 0.19652682255845944
# Metric: validation.head.pessimistic.hits_at_100 = 0.10866574965612105
# Metric: validation.tail.pessimistic.hits_at_100 = 0.2843878954607978
# Metric: validation.both.pessimistic.hits_at_100 = 0.19652682255845944
# Metric: validation.head.optimistic.adjusted_inverse_harmonic_mean_rank = 0.013771333405281996
# Metric: validation.tail.optimistic.adjusted_inverse_harmonic_mean_rank = 0.03379082619450248
# Metric: validation.both.optimistic.adjusted_inverse_harmonic_mean_rank = 0.023781355978003887
# Metric: validation.head.realistic.adjusted_inverse_harmonic_mean_rank = 0.013771045722115943
# Metric: validation.tail.realistic.adjusted_inverse_harmonic_mean_rank = 0.03379076380244085
# Metric: validation.both.realistic.adjusted_inverse_harmonic_mean_rank = 0.023781182257180896
# Metric: validation.head.pessimistic.adjusted_inverse_harmonic_mean_rank = 0.013770762756511007
# Metric: validation.tail.pessimistic.adjusted_inverse_harmonic_mean_rank = 0.03379070518311559
# Metric: validation.both.pessimistic.adjusted_inverse_harmonic_mean_rank = 0.023781010154127914
# Metric: validation.head.optimistic.harmonic_mean_rank = 65.7183470354964
# Metric: validation.tail.optimistic.harmonic_mean_rank = 28.44677590631286
# Metric: validation.both.optimistic.harmonic_mean_rank = 39.70631657768527
# Metric: validation.head.realistic.harmonic_mean_rank = 65.71958771347677
# Metric: validation.tail.realistic.harmonic_mean_rank = 28.44682632404857
# Metric: validation.both.realistic.harmonic_mean_rank = 39.706590072575764
# Metric: validation.head.pessimistic.harmonic_mean_rank = 65.72080809194762
# Metric: validation.tail.pessimistic.harmonic_mean_rank = 28.446873693276824
# Metric: validation.both.pessimistic.harmonic_mean_rank = 39.7068610242684
# Metric: validation.head.optimistic.adjusted_arithmetic_mean_rank_index = 0.44858218209666323
# Metric: validation.tail.optimistic.adjusted_arithmetic_mean_rank_index = 0.8147245912794564
# Metric: validation.both.optimistic.adjusted_arithmetic_mean_rank_index = 0.6352372636245684
# Metric: validation.head.realistic.adjusted_arithmetic_mean_rank_index = 0.44846134154835626
# Metric: validation.tail.realistic.adjusted_arithmetic_mean_rank_index = 0.8147067047616742
# Metric: validation.both.realistic.adjusted_arithmetic_mean_rank_index = 0.6351689171838819
# Metric: validation.head.pessimistic.adjusted_arithmetic_mean_rank_index = 0.4483405296715731
# Metric: validation.tail.pessimistic.adjusted_arithmetic_mean_rank_index = 0.8146888098111545
# Metric: validation.both.pessimistic.adjusted_arithmetic_mean_rank_index = 0.6351005617849876
# Metric: validation.head.optimistic.geometric_mean_rank = 815.1044597932149
# Metric: validation.tail.optimistic.geometric_mean_rank = 198.85118185607496
# Metric: validation.both.optimistic.geometric_mean_rank = 402.5971748112975
# Metric: validation.head.realistic.geometric_mean_rank = 815.2999267578125
# Metric: validation.tail.realistic.geometric_mean_rank = 198.86305236816406
# Metric: validation.both.realistic.geometric_mean_rank = 402.6573791503906
# Metric: validation.head.pessimistic.geometric_mean_rank = 815.4944600475078
# Metric: validation.tail.pessimistic.geometric_mean_rank = 198.8746676015847
# Metric: validation.both.pessimistic.geometric_mean_rank = 402.7172577291445
# Metric: validation.head.optimistic.z_arithmetic_mean_rank = 41.81614989301261
# Metric: validation.tail.optimistic.z_arithmetic_mean_rank = 76.08574360265226
# Metric: validation.both.optimistic.z_arithmetic_mean_rank = 83.80696530339634
# Metric: validation.head.realistic.z_arithmetic_mean_rank = 41.80488532058233
# Metric: validation.tail.realistic.z_arithmetic_mean_rank = 76.0840732111844
# Metric: validation.both.realistic.z_arithmetic_mean_rank = 83.79794834530648
# Metric: validation.head.pessimistic.z_arithmetic_mean_rank = 41.79362342086797
# Metric: validation.tail.pessimistic.z_arithmetic_mean_rank = 76.08240203219755
# Metric: validation.both.pessimistic.z_arithmetic_mean_rank = 83.78893020535865
# Metric: validation.head.optimistic.median_absolute_deviation = 1498.9108429091636
# Metric: validation.tail.optimistic.median_absolute_deviation = 362.49624242461965
# Metric: validation.both.optimistic.median_absolute_deviation = 707.2012582271722
# Metric: validation.head.realistic.median_absolute_deviation = 1498.9108429091636
# Metric: validation.tail.realistic.median_absolute_deviation = 362.49624242461965
# Metric: validation.both.realistic.median_absolute_deviation = 707.2012582271722
# Metric: validation.head.pessimistic.median_absolute_deviation = 1500.393445127669
# Metric: validation.tail.pessimistic.median_absolute_deviation = 362.49624242461965
# Metric: validation.both.pessimistic.median_absolute_deviation = 707.2012582271722
# Metric: validation.head.optimistic.standard_deviation = 1616.224682636022
# Metric: validation.tail.optimistic.standard_deviation = 1045.347538101686
# Metric: validation.both.optimistic.standard_deviation = 1476.9654317209424
# Metric: validation.head.realistic.standard_deviation = 1616.4268798828125
# Metric: validation.tail.realistic.standard_deviation = 1045.3719482421875
# Metric: validation.both.realistic.standard_deviation = 1477.1483154296875
# Metric: validation.head.pessimistic.standard_deviation = 1616.631309436558
# Metric: validation.tail.pessimistic.standard_deviation = 1045.3972119531995
# Metric: validation.both.pessimistic.standard_deviation = 1477.332441192907
# Metric: validation.head.optimistic.median_rank = 1228.5
# Metric: validation.tail.optimistic.median_rank = 287.0
# Metric: validation.both.optimistic.median_rank = 536.0
# Metric: validation.head.realistic.median_rank = 1228.5
# Metric: validation.tail.realistic.median_rank = 287.0
# Metric: validation.both.realistic.median_rank = 536.0
# Metric: validation.head.pessimistic.median_rank = 1228.5
# Metric: validation.tail.pessimistic.median_rank = 287.0
# Metric: validation.both.pessimistic.median_rank = 536.0
# Metric: validation.head.optimistic.z_inverse_harmonic_mean_rank = 46.34330634972678
# Metric: validation.tail.optimistic.z_inverse_harmonic_mean_rank = 116.18269754782169
# Metric: validation.both.optimistic.z_inverse_harmonic_mean_rank = 114.38750301793834
# Metric: validation.head.realistic.z_inverse_harmonic_mean_rank = 46.342338238019394
# Metric: validation.tail.realistic.z_inverse_harmonic_mean_rank = 116.18248302575041
# Metric: validation.both.realistic.z_inverse_harmonic_mean_rank = 114.38666742676422
# Metric: validation.head.pessimistic.z_inverse_harmonic_mean_rank = 46.34138600185387
# Metric: validation.tail.pessimistic.z_inverse_harmonic_mean_rank = 116.18228147544508
# Metric: validation.both.pessimistic.z_inverse_harmonic_mean_rank = 114.3858396170081
# Metric: validation.head.optimistic.inverse_harmonic_mean_rank = 0.01521645088638445
# Metric: validation.tail.optimistic.inverse_harmonic_mean_rank = 0.035153368638098696
# Metric: validation.both.optimistic.inverse_harmonic_mean_rank = 0.025184909762241567
# Metric: validation.head.realistic.inverse_harmonic_mean_rank = 0.015216163624759553
# Metric: validation.tail.realistic.inverse_harmonic_mean_rank = 0.035153306334021986
# Metric: validation.both.realistic.inverse_harmonic_mean_rank = 0.025184736291184878
# Metric: validation.head.pessimistic.inverse_harmonic_mean_rank = 0.015215881073783147
# Metric: validation.tail.pessimistic.inverse_harmonic_mean_rank = 0.03515324779736135
# Metric: validation.both.pessimistic.inverse_harmonic_mean_rank = 0.025184564435572255
# Metric: validation.head.optimistic.adjusted_geometric_mean_rank_index = 0.6535402820880645
# Metric: validation.tail.optimistic.adjusted_geometric_mean_rank_index = 0.9191890507620433
# Metric: validation.both.optimistic.adjusted_geometric_mean_rank_index = 0.8325520742434064
# Metric: validation.head.realistic.adjusted_geometric_mean_rank_index = 0.6534570969039017
# Metric: validation.tail.realistic.adjusted_geometric_mean_rank_index = 0.9191842023333361
# Metric: validation.both.realistic.adjusted_geometric_mean_rank_index = 0.8325269717468378
# Metric: validation.head.pessimistic.adjusted_geometric_mean_rank_index = 0.6533743090652386
# Metric: validation.tail.pessimistic.adjusted_geometric_mean_rank_index = 0.9191794581714385
# Metric: validation.both.pessimistic.adjusted_geometric_mean_rank_index = 0.8325020050776517
# Metric: validation.head.optimistic.inverse_geometric_mean_rank = 0.0012268366195097148
# Metric: validation.tail.optimistic.inverse_geometric_mean_rank = 0.005028886379583012
# Metric: validation.both.optimistic.inverse_geometric_mean_rank = 0.0024838723730952975
# Metric: validation.head.realistic.inverse_geometric_mean_rank = 0.001226542517542839
# Metric: validation.tail.realistic.inverse_geometric_mean_rank = 0.005028586369007826
# Metric: validation.both.realistic.inverse_geometric_mean_rank = 0.002483501099050045
# Metric: validation.head.pessimistic.inverse_geometric_mean_rank = 0.0012262498998972275
# Metric: validation.tail.pessimistic.inverse_geometric_mean_rank = 0.005028292502307779
# Metric: validation.both.pessimistic.inverse_geometric_mean_rank = 0.0024831317278003764
# Metric: validation.head.optimistic.adjusted_arithmetic_mean_rank = 0.5515580633296948
# Metric: validation.tail.optimistic.adjusted_arithmetic_mean_rank = 0.1855203470213853
# Metric: validation.both.optimistic.adjusted_arithmetic_mean_rank = 0.36495745122101936
# Metric: validation.head.realistic.adjusted_arithmetic_mean_rank = 0.5516788660982261
# Metric: validation.tail.realistic.adjusted_arithmetic_mean_rank = 0.18553822816177581
# Metric: validation.both.realistic.adjusted_arithmetic_mean_rank = 0.36502577671194836
# Metric: validation.head.pessimistic.adjusted_arithmetic_mean_rank = 0.5517996402041975
# Metric: validation.tail.pessimistic.adjusted_arithmetic_mean_rank = 0.1855561177323685
# Metric: validation.both.pessimistic.adjusted_arithmetic_mean_rank = 0.36509411115833923
# Metric: validation.head.optimistic.inverse_arithmetic_mean_rank = 0.0005668334225101871
# Metric: validation.tail.optimistic.inverse_arithmetic_mean_rank = 0.001620519747716059
# Metric: validation.both.optimistic.inverse_arithmetic_mean_rank = 0.0008398870080483877
# Metric: validation.head.realistic.inverse_arithmetic_mean_rank = 0.0005667093209922314
# Metric: validation.tail.realistic.inverse_arithmetic_mean_rank = 0.0016203635605052114
# Metric: validation.both.realistic.inverse_arithmetic_mean_rank = 0.00083972979336977
# Metric: validation.head.pessimistic.inverse_arithmetic_mean_rank = 0.0005665852638732533
# Metric: validation.tail.pessimistic.inverse_arithmetic_mean_rank = 0.0016202073508829796
# Metric: validation.both.pessimistic.inverse_arithmetic_mean_rank = 0.0008395726263523601
# Metric: validation.head.optimistic.arithmetic_mean_rank = 1764.1867262723522
# Metric: validation.tail.optimistic.arithmetic_mean_rank = 617.085969738652
# Metric: validation.both.optimistic.arithmetic_mean_rank = 1190.636348005502
# Metric: validation.head.realistic.arithmetic_mean_rank = 1764.5731201171875
# Metric: validation.tail.realistic.arithmetic_mean_rank = 617.1454467773438
# Metric: validation.both.realistic.arithmetic_mean_rank = 1190.8592529296875
# Metric: validation.head.pessimistic.arithmetic_mean_rank = 1764.9594222833562
# Metric: validation.tail.pessimistic.arithmetic_mean_rank = 617.2049518569463
# Metric: validation.both.pessimistic.arithmetic_mean_rank = 1191.0821870701513
# Metric: validation.head.optimistic.count = 2908.0
# Metric: validation.tail.optimistic.count = 2908.0
# Metric: validation.both.optimistic.count = 5816.0
# Metric: validation.head.realistic.count = 2908.0
# Metric: validation.tail.realistic.count = 2908.0
# Metric: validation.both.realistic.count = 5816.0
# Metric: validation.head.pessimistic.count = 2908.0
# Metric: validation.tail.pessimistic.count = 2908.0
# Metric: validation.both.pessimistic.count = 5816.0
# Metric: validation.head.optimistic.variance = 2612182.22476191
# Metric: validation.tail.optimistic.variance = 1092751.475415256
# Metric: validation.both.optimistic.variance = 2181426.8864986296
# Metric: validation.head.realistic.variance = 2612836.0
# Metric: validation.tail.realistic.variance = 1092802.625
# Metric: validation.both.realistic.variance = 2181967.0
# Metric: validation.head.pessimistic.variance = 2613496.7906505605
# Metric: validation.tail.pessimistic.variance = 1092855.330759523
# Metric: validation.both.pessimistic.variance = 2182511.141800994
# Metric: validation.head.optimistic.inverse_median_rank = 0.000814000814000814
# Metric: validation.tail.optimistic.inverse_median_rank = 0.003484320557491289
# Metric: validation.both.optimistic.inverse_median_rank = 0.0018656716417910447
# Metric: validation.head.realistic.inverse_median_rank = 0.0008140008430927992
# Metric: validation.tail.realistic.inverse_median_rank = 0.003484320593997836
# Metric: validation.both.realistic.inverse_median_rank = 0.0018656715983524919
# Metric: validation.head.pessimistic.inverse_median_rank = 0.000814000814000814
# Metric: validation.tail.pessimistic.inverse_median_rank = 0.003484320557491289
# Metric: validation.both.pessimistic.inverse_median_rank = 0.0018656716417910447
# Metric: validation.head.optimistic.z_geometric_mean_rank = 35.364028997519576
# Metric: validation.tail.optimistic.z_geometric_mean_rank = 49.73355338037701
# Metric: validation.both.optimistic.z_geometric_mean_rank = 63.69999171169466
# Metric: validation.head.realistic.z_geometric_mean_rank = 35.35952772446033
# Metric: validation.tail.realistic.z_geometric_mean_rank = 49.73329105176494
# Metric: validation.both.realistic.z_geometric_mean_rank = 63.698071076490166
# Metric: validation.head.pessimistic.z_geometric_mean_rank = 35.35504795235237
# Metric: validation.tail.pessimistic.z_geometric_mean_rank = 49.73303436460273
# Metric: validation.both.pessimistic.z_geometric_mean_rank = 63.696160833672415
# Metric: validation.head.optimistic.z_hits_at_k = 39.082193003564385
# Metric: validation.tail.optimistic.z_hits_at_k = 113.73301386574855
# Metric: validation.both.optimistic.z_hits_at_k = 107.48168335500326
# Metric: validation.head.realistic.z_hits_at_k = 39.082193003564385
# Metric: validation.tail.realistic.z_hits_at_k = 113.73301386574855
# Metric: validation.both.realistic.z_hits_at_k = 107.48168335500326
# Metric: validation.head.pessimistic.z_hits_at_k = 39.082193003564385
# Metric: validation.tail.pessimistic.z_hits_at_k = 113.73301386574855
# Metric: validation.both.pessimistic.z_hits_at_k = 107.48168335500326
# Metric: validation.head.optimistic.adjusted_hits_at_k = 0.02873670478630913
# Metric: validation.tail.optimistic.adjusted_hits_at_k = 0.08183832124487367
# Metric: validation.both.optimistic.adjusted_hits_at_k = 0.05528839491925885
# Metric: validation.head.realistic.adjusted_hits_at_k = 0.02873670478630913
# Metric: validation.tail.realistic.adjusted_hits_at_k = 0.08183832124487367
# Metric: validation.both.realistic.adjusted_hits_at_k = 0.05528839491925885
# Metric: validation.head.pessimistic.adjusted_hits_at_k = 0.02873670478630913
# Metric: validation.tail.pessimistic.adjusted_hits_at_k = 0.08183832124487367
# Metric: validation.both.pessimistic.adjusted_hits_at_k = 0.05528839491925885
# Step: 1
# Metric: loss = 0.0023624341261265225
# Training batches on cuda:0:   0%|          | 0/614 [00:00<?, ?batch/s]
# Evaluating on cuda:0:   0%|          | 0.00/2.91k [00:00<?, ?triple/s]
# INFO:pykeen.evaluation.evaluator:Evaluation took 0.58s seconds
# Step: 2
# Metric: validation.head.optimistic.hits_at_1 = 0.006533700137551582
# Metric: validation.tail.optimistic.hits_at_1 = 0.019944979367262722
# Metric: validation.both.optimistic.hits_at_1 = 0.013239339752407153
# Metric: validation.head.realistic.hits_at_1 = 0.006533700137551582
# Metric: validation.tail.realistic.hits_at_1 = 0.019944979367262722
# Metric: validation.both.realistic.hits_at_1 = 0.013239339752407153
# Metric: validation.head.pessimistic.hits_at_1 = 0.006533700137551582
# Metric: validation.tail.pessimistic.hits_at_1 = 0.019944979367262722
# Metric: validation.both.pessimistic.hits_at_1 = 0.013239339752407153
# Metric: validation.head.optimistic.hits_at_3 = 0.013067400275103164
# Metric: validation.tail.optimistic.hits_at_3 = 0.045048143053645115
# Metric: validation.both.optimistic.hits_at_3 = 0.02905777166437414
# Metric: validation.head.realistic.hits_at_3 = 0.013067400275103164
# Metric: validation.tail.realistic.hits_at_3 = 0.045048143053645115
# Metric: validation.both.realistic.hits_at_3 = 0.02905777166437414
# Metric: validation.head.pessimistic.hits_at_3 = 0.013067400275103164
# Metric: validation.tail.pessimistic.hits_at_3 = 0.045048143053645115
# Metric: validation.both.pessimistic.hits_at_3 = 0.02905777166437414
# Metric: validation.head.optimistic.hits_at_5 = 0.020976616231086657
# Metric: validation.tail.optimistic.hits_at_5 = 0.0718707015130674
# Metric: validation.both.optimistic.hits_at_5 = 0.04642365887207703
# Metric: validation.head.realistic.hits_at_5 = 0.020976616231086657
# Metric: validation.tail.realistic.hits_at_5 = 0.0718707015130674
# Metric: validation.both.realistic.hits_at_5 = 0.04642365887207703
# Metric: validation.head.pessimistic.hits_at_5 = 0.020976616231086657
# Metric: validation.tail.pessimistic.hits_at_5 = 0.0718707015130674
# Metric: validation.both.pessimistic.hits_at_5 = 0.04642365887207703
# Metric: validation.head.optimistic.hits_at_10 = 0.033356258596973866
# Metric: validation.tail.optimistic.hits_at_10 = 0.11760660247592847
# Metric: validation.both.optimistic.hits_at_10 = 0.07548143053645116
# Metric: validation.head.realistic.hits_at_10 = 0.033356258596973866
# Metric: validation.tail.realistic.hits_at_10 = 0.11760660247592847
# Metric: validation.both.realistic.hits_at_10 = 0.07548143053645116
# Metric: validation.head.pessimistic.hits_at_10 = 0.033356258596973866
# Metric: validation.tail.pessimistic.hits_at_10 = 0.11760660247592847
# Metric: validation.both.pessimistic.hits_at_10 = 0.07548143053645116
# Metric: validation.head.optimistic.hits_at_100 = 0.11966987620357634
# Metric: validation.tail.optimistic.hits_at_100 = 0.390302613480055
# Metric: validation.both.optimistic.hits_at_100 = 0.2549862448418157
# Metric: validation.head.realistic.hits_at_100 = 0.11966987620357634
# Metric: validation.tail.realistic.hits_at_100 = 0.390302613480055
# Metric: validation.both.realistic.hits_at_100 = 0.2549862448418157
# Metric: validation.head.pessimistic.hits_at_100 = 0.11966987620357634
# Metric: validation.tail.pessimistic.hits_at_100 = 0.390302613480055
# Metric: validation.both.pessimistic.hits_at_100 = 0.2549862448418157
# Metric: validation.head.optimistic.adjusted_inverse_harmonic_mean_rank = 0.015227419382709611
# Metric: validation.tail.optimistic.adjusted_inverse_harmonic_mean_rank = 0.05231100395148865
# Metric: validation.both.optimistic.adjusted_inverse_harmonic_mean_rank = 0.03376972325220608
# Metric: validation.head.realistic.adjusted_inverse_harmonic_mean_rank = 0.015226939439767577
# Metric: validation.tail.realistic.adjusted_inverse_harmonic_mean_rank = 0.052310979254121995
# Metric: validation.both.realistic.adjusted_inverse_harmonic_mean_rank = 0.03376947290885633
# Metric: validation.head.pessimistic.adjusted_inverse_harmonic_mean_rank = 0.015226473831162097
# Metric: validation.tail.pessimistic.adjusted_inverse_harmonic_mean_rank = 0.05231095805407072
# Metric: validation.both.pessimistic.adjusted_inverse_harmonic_mean_rank = 0.033769227540134505
# Metric: validation.head.optimistic.harmonic_mean_rank = 59.986551257461514
# Metric: validation.tail.optimistic.harmonic_mean_rank = 18.640222133854643
# Metric: validation.both.optimistic.harmonic_mean_rank = 28.442287334314912
# Metric: validation.head.realistic.harmonic_mean_rank = 59.98827579656444
# Metric: validation.tail.realistic.harmonic_mean_rank = 18.64023070305198
# Metric: validation.both.realistic.harmonic_mean_rank = 28.442489563267177
# Metric: validation.head.pessimistic.harmonic_mean_rank = 59.98994892404798
# Metric: validation.tail.pessimistic.harmonic_mean_rank = 18.640238058798875
# Metric: validation.both.pessimistic.harmonic_mean_rank = 28.44268777647395
# Metric: validation.head.optimistic.adjusted_arithmetic_mean_rank_index = 0.4254432364691042
# Metric: validation.tail.optimistic.adjusted_arithmetic_mean_rank_index = 0.7972295215728127
# Metric: validation.both.optimistic.adjusted_arithmetic_mean_rank_index = 0.6149754993716092
# Metric: validation.head.realistic.adjusted_arithmetic_mean_rank_index = 0.4253221058973058
# Metric: validation.tail.realistic.adjusted_arithmetic_mean_rank_index = 0.7972116239965306
# Metric: validation.both.realistic.adjusted_arithmetic_mean_rank_index = 0.6149070051204935
# Metric: validation.head.pessimistic.adjusted_arithmetic_mean_rank_index = 0.42520093877719134
# Metric: validation.tail.pessimistic.adjusted_arithmetic_mean_rank_index = 0.7971937401045108
# Metric: validation.both.pessimistic.adjusted_arithmetic_mean_rank_index = 0.614838481214621
# Metric: validation.head.optimistic.geometric_mean_rank = 808.7083043251293
# Metric: validation.tail.optimistic.geometric_mean_rank = 145.53224879436684
# Metric: validation.both.optimistic.geometric_mean_rank = 343.06433528875493
# Metric: validation.head.realistic.geometric_mean_rank = 808.9019775390625
# Metric: validation.tail.realistic.geometric_mean_rank = 145.5375213623047
# Metric: validation.both.realistic.geometric_mean_rank = 343.1115417480469
# Metric: validation.head.pessimistic.geometric_mean_rank = 809.0946928669348
# Metric: validation.tail.pessimistic.geometric_mean_rank = 145.54274639503552
# Metric: validation.both.pessimistic.geometric_mean_rank = 343.15865673694077
# Metric: validation.head.optimistic.z_arithmetic_mean_rank = 39.6591725155211
# Metric: validation.tail.optimistic.z_arithmetic_mean_rank = 74.45190880466268
# Metric: validation.both.optimistic.z_arithmetic_mean_rank = 81.13382713759609
# Metric: validation.head.realistic.z_arithmetic_mean_rank = 39.64788090754133
# Metric: validation.tail.realistic.z_arithmetic_mean_rank = 74.45023738046032
# Metric: validation.both.realistic.z_arithmetic_mean_rank = 81.12479067884999
# Metric: validation.head.pessimistic.z_arithmetic_mean_rank = 39.63658589258302
# Metric: validation.tail.pessimistic.z_arithmetic_mean_rank = 74.44856723420797
# Metric: validation.both.pessimistic.z_arithmetic_mean_rank = 81.11575030774651
# Metric: validation.head.optimistic.median_absolute_deviation = 1670.1513991465606
# Metric: validation.tail.optimistic.median_absolute_deviation = 227.5794405406099
# Metric: validation.both.optimistic.median_absolute_deviation = 684.9622249495881
# Metric: validation.head.realistic.median_absolute_deviation = 1670.1513991465606
# Metric: validation.tail.realistic.median_absolute_deviation = 227.5794405406099
# Metric: validation.both.realistic.median_absolute_deviation = 684.9622249495881
# Metric: validation.head.pessimistic.median_absolute_deviation = 1670.1513991465606
# Metric: validation.tail.pessimistic.median_absolute_deviation = 227.5794405406099
# Metric: validation.both.pessimistic.median_absolute_deviation = 684.9622249495881
# Metric: validation.head.optimistic.standard_deviation = 1682.902431914258
# Metric: validation.tail.optimistic.standard_deviation = 1243.2166908872007
# Metric: validation.both.optimistic.standard_deviation = 1589.6433651812763
# Metric: validation.head.realistic.standard_deviation = 1683.1343994140625
# Metric: validation.tail.realistic.standard_deviation = 1243.266357421875
# Metric: validation.both.realistic.standard_deviation = 1589.845458984375
# Metric: validation.head.pessimistic.standard_deviation = 1683.368309183561
# Metric: validation.tail.pessimistic.standard_deviation = 1243.3166087523084
# Metric: validation.both.pessimistic.standard_deviation = 1590.0489932840949
# Metric: validation.head.optimistic.median_rank = 1320.5
# Metric: validation.tail.optimistic.median_rank = 164.0
# Metric: validation.both.optimistic.median_rank = 484.0
# Metric: validation.head.realistic.median_rank = 1320.5
# Metric: validation.tail.realistic.median_rank = 164.0
# Metric: validation.both.realistic.median_rank = 484.0
# Metric: validation.head.pessimistic.median_rank = 1320.5
# Metric: validation.tail.pessimistic.median_rank = 164.0
# Metric: validation.both.pessimistic.median_rank = 484.0
# Metric: validation.head.optimistic.z_inverse_harmonic_mean_rank = 51.24332848538921
# Metric: validation.tail.optimistic.z_inverse_harmonic_mean_rank = 179.86046021885957
# Metric: validation.both.optimistic.z_inverse_harmonic_mean_rank = 162.43120552080887
# Metric: validation.head.realistic.z_inverse_harmonic_mean_rank = 51.24171338087184
# Metric: validation.tail.realistic.z_inverse_harmonic_mean_rank = 179.8603753021232
# Metric: validation.both.realistic.z_inverse_harmonic_mean_rank = 162.43000137792058
# Metric: validation.head.pessimistic.z_inverse_harmonic_mean_rank = 51.24014651427965
# Metric: validation.tail.pessimistic.z_inverse_harmonic_mean_rank = 179.86030241017522
# Metric: validation.both.pessimistic.z_inverse_harmonic_mean_rank = 162.42882116282124
# Metric: validation.head.optimistic.inverse_harmonic_mean_rank = 0.016670403266025625
# Metric: validation.tail.optimistic.inverse_harmonic_mean_rank = 0.05364742935030723
# Metric: validation.both.optimistic.inverse_harmonic_mean_rank = 0.03515891630816643
# Metric: validation.head.realistic.inverse_harmonic_mean_rank = 0.016669924026342337
# Metric: validation.tail.realistic.inverse_harmonic_mean_rank = 0.05364740468776866
# Metric: validation.both.realistic.inverse_harmonic_mean_rank = 0.03515866632474666
# Metric: validation.head.pessimistic.inverse_harmonic_mean_rank = 0.01666945909999155
# Metric: validation.tail.pessimistic.inverse_harmonic_mean_rank = 0.05364738351761357
# Metric: validation.both.pessimistic.inverse_harmonic_mean_rank = 0.03515842130880257
# Metric: validation.head.optimistic.adjusted_geometric_mean_rank_index = 0.6562623040504016
# Metric: validation.tail.optimistic.adjusted_geometric_mean_rank_index = 0.9409668008500163
# Metric: validation.both.optimistic.adjusted_geometric_mean_rank_index = 0.8573745857492057
# Metric: validation.head.realistic.adjusted_geometric_mean_rank_index = 0.656179882235536
# Metric: validation.tail.realistic.adjusted_geometric_mean_rank_index = 0.9409646473060446
# Metric: validation.both.realistic.adjusted_geometric_mean_rank_index = 0.8573549027828241
# Metric: validation.head.pessimistic.adjusted_geometric_mean_rank_index = 0.6560978680697509
# Metric: validation.tail.pessimistic.adjusted_geometric_mean_rank_index = 0.9409625131775
# Metric: validation.both.pessimistic.adjusted_geometric_mean_rank_index = 0.8573352579554768
# Metric: validation.head.optimistic.inverse_geometric_mean_rank = 0.0012365397939551324
# Metric: validation.tail.optimistic.inverse_geometric_mean_rank = 0.0068713292640243135
# Metric: validation.both.optimistic.inverse_geometric_mean_rank = 0.002914905156661962
# Metric: validation.head.realistic.inverse_geometric_mean_rank = 0.001236243755556643
# Metric: validation.tail.realistic.inverse_geometric_mean_rank = 0.006871080491691828
# Metric: validation.both.realistic.inverse_geometric_mean_rank = 0.002914504148066044
# Metric: validation.head.pessimistic.inverse_geometric_mean_rank = 0.0012359492761676808
# Metric: validation.tail.pessimistic.inverse_geometric_mean_rank = 0.0068708336538172545
# Metric: validation.both.pessimistic.inverse_geometric_mean_rank = 0.0029141039585272124
# Metric: validation.head.optimistic.adjusted_arithmetic_mean_rank = 0.574689774761549
# Metric: validation.tail.optimistic.adjusted_arithmetic_mean_rank = 0.20301015702101521
# Metric: validation.both.optimistic.adjusted_arithmetic_mean_rank = 0.3852130047767734
# Metric: validation.head.realistic.adjusted_arithmetic_mean_rank = 0.5748108674628983
# Metric: validation.tail.realistic.adjusted_arithmetic_mean_rank = 0.20302804921658105
# Metric: validation.both.realistic.adjusted_arithmetic_mean_rank = 0.3852814780328242
# Metric: validation.head.pessimistic.adjusted_arithmetic_mean_rank = 0.5749319967011371
# Metric: validation.tail.pessimistic.adjusted_arithmetic_mean_rank = 0.2030459277319984
# Metric: validation.both.pessimistic.adjusted_arithmetic_mean_rank = 0.3853499809345421
# Metric: validation.head.optimistic.inverse_arithmetic_mean_rank = 0.0005440179353808463
# Metric: validation.tail.optimistic.inverse_arithmetic_mean_rank = 0.0014809081001802755
# Metric: validation.both.optimistic.inverse_arithmetic_mean_rank = 0.00079572345162286
# Metric: validation.head.realistic.inverse_arithmetic_mean_rank = 0.0005439033266156912
# Metric: validation.tail.realistic.inverse_arithmetic_mean_rank = 0.0014807776315137744
# Metric: validation.both.realistic.inverse_arithmetic_mean_rank = 0.000795582018326968
# Metric: validation.head.pessimistic.inverse_arithmetic_mean_rank = 0.000543788737701408
# Metric: validation.tail.pessimistic.inverse_arithmetic_mean_rank = 0.0014806472077987542
# Metric: validation.both.pessimistic.inverse_arithmetic_mean_rank = 0.0007954406044801524
# Metric: validation.head.optimistic.arithmetic_mean_rank = 1838.1746905089408
# Metric: validation.tail.optimistic.arithmetic_mean_rank = 675.2613480055021
# Metric: validation.both.optimistic.arithmetic_mean_rank = 1256.7180192572214
# Metric: validation.head.realistic.arithmetic_mean_rank = 1838.56201171875
# Metric: validation.tail.realistic.arithmetic_mean_rank = 675.3208618164062
# Metric: validation.both.realistic.arithmetic_mean_rank = 1256.94140625
# Metric: validation.head.pessimistic.arithmetic_mean_rank = 1838.9494497936726
# Metric: validation.tail.pessimistic.arithmetic_mean_rank = 675.3803301237964
# Metric: validation.both.pessimistic.arithmetic_mean_rank = 1257.1648899587344
# Metric: validation.head.optimistic.count = 2908.0
# Metric: validation.tail.optimistic.count = 2908.0
# Metric: validation.both.optimistic.count = 5816.0
# Metric: validation.head.realistic.count = 2908.0
# Metric: validation.tail.realistic.count = 2908.0
# Metric: validation.both.realistic.count = 5816.0
# Metric: validation.head.pessimistic.count = 2908.0
# Metric: validation.tail.pessimistic.count = 2908.0
# Metric: validation.both.pessimistic.count = 5816.0
# Metric: validation.head.optimistic.variance = 2832160.5953429234
# Metric: validation.tail.optimistic.variance = 1545587.7405005214
# Metric: validation.both.optimistic.variance = 2526966.0284648524
# Metric: validation.head.realistic.variance = 2832941.25
# Metric: validation.tail.realistic.variance = 1545711.25
# Metric: validation.both.realistic.variance = 2527608.75
# Metric: validation.head.pessimistic.variance = 2833728.8643635213
# Metric: validation.tail.pessimistic.variance = 1545836.1895993408
# Metric: validation.both.pessimistic.variance = 2528255.8010437638
# Metric: validation.head.optimistic.inverse_median_rank = 0.0007572889057175312
# Metric: validation.tail.optimistic.inverse_median_rank = 0.006097560975609756
# Metric: validation.both.optimistic.inverse_median_rank = 0.002066115702479339
# Metric: validation.head.realistic.inverse_median_rank = 0.0007572888862341642
# Metric: validation.tail.realistic.inverse_median_rank = 0.006097560748457909
# Metric: validation.both.realistic.inverse_median_rank = 0.00206611561588943
# Metric: validation.head.pessimistic.inverse_median_rank = 0.0007572889057175312
# Metric: validation.tail.pessimistic.inverse_median_rank = 0.006097560975609756
# Metric: validation.both.pessimistic.inverse_median_rank = 0.002066115702479339
# Metric: validation.head.optimistic.z_geometric_mean_rank = 35.51132162239102
# Metric: validation.tail.optimistic.z_geometric_mean_rank = 50.911858208537005
# Metric: validation.both.optimistic.z_geometric_mean_rank = 65.59920477727952
# Metric: validation.head.realistic.z_geometric_mean_rank = 35.50686165637083
# Metric: validation.tail.realistic.z_geometric_mean_rank = 50.911741689096324
# Metric: validation.both.realistic.z_geometric_mean_rank = 65.59769879965462
# Metric: validation.head.pessimistic.z_geometric_mean_rank = 35.502423748843896
# Metric: validation.tail.pessimistic.z_geometric_mean_rank = 50.91162622014486
# Metric: validation.both.pessimistic.z_geometric_mean_rank = 65.59619574011288
# Metric: validation.head.optimistic.z_hits_at_k = 43.29791861751382
# Metric: validation.tail.optimistic.z_hits_at_k = 161.59479466291396
# Metric: validation.both.optimistic.z_hits_at_k = 143.97139425812267
# Metric: validation.head.realistic.z_hits_at_k = 43.29791861751382
# Metric: validation.tail.realistic.z_hits_at_k = 161.59479466291396
# Metric: validation.both.realistic.z_hits_at_k = 143.97139425812267
# Metric: validation.head.pessimistic.z_hits_at_k = 43.29791861751382
# Metric: validation.tail.pessimistic.z_hits_at_k = 161.59479466291396
# Metric: validation.both.pessimistic.z_hits_at_k = 143.97139425812267
# Metric: validation.head.optimistic.adjusted_hits_at_k = 0.03183648126039538
# Metric: validation.tail.optimistic.adjusted_hits_at_k = 0.11627799411640878
# Metric: validation.both.optimistic.adjusted_hits_at_k = 0.07405864008035996
# Metric: validation.head.realistic.adjusted_hits_at_k = 0.03183648126039538
# Metric: validation.tail.realistic.adjusted_hits_at_k = 0.11627799411640878
# Metric: validation.both.realistic.adjusted_hits_at_k = 0.07405864008035996
# Metric: validation.head.pessimistic.adjusted_hits_at_k = 0.03183648126039538
# Metric: validation.tail.pessimistic.adjusted_hits_at_k = 0.11627799411640878
# Metric: validation.both.pessimistic.adjusted_hits_at_k = 0.07405864008035996
# Step: 2
# Metric: loss = 0.0008741866717386554
# Training batches on cuda:0:   0%|          | 0/614 [00:00<?, ?batch/s]
# Evaluating on cuda:0:   0%|          | 0.00/2.91k [00:00<?, ?triple/s]
# INFO:pykeen.evaluation.evaluator:Evaluation took 0.57s seconds
# Step: 3
# Metric: validation.head.optimistic.hits_at_1 = 0.003782668500687758
# Metric: validation.tail.optimistic.hits_at_1 = 0.021320495185694635
# Metric: validation.both.optimistic.hits_at_1 = 0.012551581843191197
# Metric: validation.head.realistic.hits_at_1 = 0.003782668500687758
# Metric: validation.tail.realistic.hits_at_1 = 0.021320495185694635
# Metric: validation.both.realistic.hits_at_1 = 0.012551581843191197
# Metric: validation.head.pessimistic.hits_at_1 = 0.003782668500687758
# Metric: validation.tail.pessimistic.hits_at_1 = 0.021320495185694635
# Metric: validation.both.pessimistic.hits_at_1 = 0.012551581843191197
# Metric: validation.head.optimistic.hits_at_3 = 0.014099037138927097
# Metric: validation.tail.optimistic.hits_at_3 = 0.0546767537826685
# Metric: validation.both.optimistic.hits_at_3 = 0.0343878954607978
# Metric: validation.head.realistic.hits_at_3 = 0.014099037138927097
# Metric: validation.tail.realistic.hits_at_3 = 0.0546767537826685
# Metric: validation.both.realistic.hits_at_3 = 0.0343878954607978
# Metric: validation.head.pessimistic.hits_at_3 = 0.014099037138927097
# Metric: validation.tail.pessimistic.hits_at_3 = 0.0546767537826685
# Metric: validation.both.pessimistic.hits_at_3 = 0.0343878954607978
# Metric: validation.head.optimistic.hits_at_5 = 0.0202888583218707
# Metric: validation.tail.optimistic.hits_at_5 = 0.08631361760660247
# Metric: validation.both.optimistic.hits_at_5 = 0.05330123796423659
# Metric: validation.head.realistic.hits_at_5 = 0.0202888583218707
# Metric: validation.tail.realistic.hits_at_5 = 0.08631361760660247
# Metric: validation.both.realistic.hits_at_5 = 0.05330123796423659
# Metric: validation.head.pessimistic.hits_at_5 = 0.0202888583218707
# Metric: validation.tail.pessimistic.hits_at_5 = 0.08631361760660247
# Metric: validation.both.pessimistic.hits_at_5 = 0.05330123796423659
# Metric: validation.head.optimistic.hits_at_10 = 0.0374828060522696
# Metric: validation.tail.optimistic.hits_at_10 = 0.1454607977991747
# Metric: validation.both.optimistic.hits_at_10 = 0.09147180192572214
# Metric: validation.head.realistic.hits_at_10 = 0.0374828060522696
# Metric: validation.tail.realistic.hits_at_10 = 0.1454607977991747
# Metric: validation.both.realistic.hits_at_10 = 0.09147180192572214
# Metric: validation.head.pessimistic.hits_at_10 = 0.0374828060522696
# Metric: validation.tail.pessimistic.hits_at_10 = 0.1454607977991747
# Metric: validation.both.pessimistic.hits_at_10 = 0.09147180192572214
# Metric: validation.head.optimistic.hits_at_100 = 0.1358321870701513
# Metric: validation.tail.optimistic.hits_at_100 = 0.4776478679504814
# Metric: validation.both.optimistic.hits_at_100 = 0.30674002751031637
# Metric: validation.head.realistic.hits_at_100 = 0.1358321870701513
# Metric: validation.tail.realistic.hits_at_100 = 0.4776478679504814
# Metric: validation.both.realistic.hits_at_100 = 0.30674002751031637
# Metric: validation.head.pessimistic.hits_at_100 = 0.1358321870701513
# Metric: validation.tail.pessimistic.hits_at_100 = 0.4776478679504814
# Metric: validation.both.pessimistic.hits_at_100 = 0.30674002751031637
# Metric: validation.head.optimistic.adjusted_inverse_harmonic_mean_rank = 0.01480171689850863
# Metric: validation.tail.optimistic.adjusted_inverse_harmonic_mean_rank = 0.06129612336552915
# Metric: validation.both.optimistic.adjusted_inverse_harmonic_mean_rank = 0.038049561543742755
# Metric: validation.head.realistic.adjusted_inverse_harmonic_mean_rank = 0.014801345687730177
# Metric: validation.tail.realistic.adjusted_inverse_harmonic_mean_rank = 0.06129610133624346
# Metric: validation.both.realistic.adjusted_inverse_harmonic_mean_rank = 0.0380493649285278
# Metric: validation.head.pessimistic.adjusted_inverse_harmonic_mean_rank = 0.01480098264185792
# Metric: validation.tail.pessimistic.adjusted_inverse_harmonic_mean_rank = 0.06129607306597493
# Metric: validation.both.pessimistic.adjusted_inverse_harmonic_mean_rank = 0.038049169275075775
# Metric: validation.head.optimistic.harmonic_mean_rank = 61.55617243412667
# Metric: validation.tail.optimistic.harmonic_mean_rank = 15.969369981267167
# Metric: validation.both.optimistic.harmonic_mean_rank = 25.359726913334207
# Metric: validation.head.realistic.harmonic_mean_rank = 61.55757698303134
# Metric: validation.tail.realistic.harmonic_mean_rank = 15.969375591272339
# Metric: validation.both.realistic.harmonic_mean_rank = 25.35985317850649
# Metric: validation.head.pessimistic.harmonic_mean_rank = 61.55895070040775
# Metric: validation.tail.pessimistic.harmonic_mean_rank = 15.969382790619704
# Metric: validation.both.pessimistic.harmonic_mean_rank = 25.35997882728822
# Metric: validation.head.optimistic.adjusted_arithmetic_mean_rank_index = 0.4333801259324239
# Metric: validation.tail.optimistic.adjusted_arithmetic_mean_rank_index = 0.8209500496907385
# Metric: validation.both.optimistic.adjusted_arithmetic_mean_rank_index = 0.6309587016520046
# Metric: validation.head.realistic.adjusted_arithmetic_mean_rank_index = 0.43325931683877406
# Metric: validation.tail.realistic.adjusted_arithmetic_mean_rank_index = 0.8209321089156127
# Metric: validation.both.realistic.adjusted_arithmetic_mean_rank_index = 0.630890314899383
# Metric: validation.head.pessimistic.adjusted_arithmetic_mean_rank_index = 0.4331384735073338
# Metric: validation.tail.pessimistic.adjusted_arithmetic_mean_rank_index = 0.8209141648077884
# Metric: validation.both.pessimistic.adjusted_arithmetic_mean_rank_index = 0.630821947092856
# Metric: validation.head.optimistic.geometric_mean_rank = 762.5498287845187
# Metric: validation.tail.optimistic.geometric_mean_rank = 104.08245263977152
# Metric: validation.both.optimistic.geometric_mean_rank = 281.7233686436581
# Metric: validation.head.realistic.geometric_mean_rank = 762.7315673828125
# Metric: validation.tail.realistic.geometric_mean_rank = 104.08638763427734
# Metric: validation.both.realistic.geometric_mean_rank = 281.76226806640625
# Metric: validation.head.pessimistic.geometric_mean_rank = 762.9116687802984
# Metric: validation.tail.pessimistic.geometric_mean_rank = 104.09021995832862
# Metric: validation.both.pessimistic.geometric_mean_rank = 281.80071577644486
# Metric: validation.head.optimistic.z_arithmetic_mean_rank = 40.39903730000987
# Metric: validation.tail.optimistic.z_arithmetic_mean_rank = 76.66712857318068
# Metric: validation.both.optimistic.z_arithmetic_mean_rank = 83.24249386049465
# Metric: validation.head.realistic.z_arithmetic_mean_rank = 40.38777565973497
# Metric: validation.tail.realistic.z_arithmetic_mean_rank = 76.66545311471182
# Metric: validation.both.realistic.z_arithmetic_mean_rank = 83.233471584044
# Metric: validation.head.pessimistic.z_arithmetic_mean_rank = 40.37651082786524
# Metric: validation.tail.pessimistic.z_arithmetic_mean_rank = 76.6637773450079
# Metric: validation.both.pessimistic.z_arithmetic_mean_rank = 83.22445180715498
# Metric: validation.head.optimistic.median_absolute_deviation = 1722.0424767942566
# Metric: validation.tail.optimistic.median_absolute_deviation = 149.7428240690658
# Metric: validation.both.optimistic.median_absolute_deviation = 536.7020030990279
# Metric: validation.head.realistic.median_absolute_deviation = 1722.413127348883
# Metric: validation.tail.realistic.median_absolute_deviation = 149.7428240690658
# Metric: validation.both.realistic.median_absolute_deviation = 536.7020030990279
# Metric: validation.head.pessimistic.median_absolute_deviation = 1722.7837779035094
# Metric: validation.tail.pessimistic.median_absolute_deviation = 149.7428240690658
# Metric: validation.both.pessimistic.median_absolute_deviation = 536.7020030990279
# Metric: validation.head.optimistic.standard_deviation = 1678.3724654447753
# Metric: validation.tail.optimistic.standard_deviation = 1255.9844427223009
# Metric: validation.both.optimistic.standard_deviation = 1602.226459218898
# Metric: validation.head.realistic.standard_deviation = 1678.58203125
# Metric: validation.tail.realistic.standard_deviation = 1256.036376953125
# Metric: validation.both.realistic.standard_deviation = 1602.4185791015625
# Metric: validation.head.pessimistic.standard_deviation = 1678.7936301694963
# Metric: validation.tail.pessimistic.standard_deviation = 1256.0888795649535
# Metric: validation.both.pessimistic.standard_deviation = 1602.612009546209
# Metric: validation.head.optimistic.median_rank = 1327.0
# Metric: validation.tail.optimistic.median_rank = 111.0
# Metric: validation.both.optimistic.median_rank = 375.0
# Metric: validation.head.realistic.median_rank = 1327.0
# Metric: validation.tail.realistic.median_rank = 111.0
# Metric: validation.both.realistic.median_rank = 375.0
# Metric: validation.head.pessimistic.median_rank = 1327.0
# Metric: validation.tail.pessimistic.median_rank = 111.0
# Metric: validation.both.pessimistic.median_rank = 375.0
# Metric: validation.head.optimistic.z_inverse_harmonic_mean_rank = 49.81075401648565
# Metric: validation.tail.optimistic.z_inverse_harmonic_mean_rank = 210.75391648724658
# Metric: validation.both.optimistic.z_inverse_harmonic_mean_rank = 183.01708026833163
# Metric: validation.head.realistic.z_inverse_harmonic_mean_rank = 49.80950481756498
# Metric: validation.tail.realistic.z_inverse_harmonic_mean_rank = 210.75384074414927
# Metric: validation.both.realistic.z_inverse_harmonic_mean_rank = 183.01613455592081
# Metric: validation.head.pessimistic.z_inverse_harmonic_mean_rank = 49.808283095195634
# Metric: validation.tail.pessimistic.z_inverse_harmonic_mean_rank = 210.75374354273612
# Metric: validation.both.pessimistic.z_inverse_harmonic_mean_rank = 183.01519346955664
# Metric: validation.head.optimistic.inverse_harmonic_mean_rank = 0.016245324562214027
# Metric: validation.tail.optimistic.inverse_harmonic_mean_rank = 0.06261987800226607
# Metric: validation.both.optimistic.inverse_harmonic_mean_rank = 0.039432601282240055
# Metric: validation.head.realistic.inverse_harmonic_mean_rank = 0.016244953895369455
# Metric: validation.tail.realistic.inverse_harmonic_mean_rank = 0.06261985600404595
# Metric: validation.both.realistic.inverse_harmonic_mean_rank = 0.039432404949707706
# Metric: validation.head.pessimistic.inverse_harmonic_mean_rank = 0.01624459138146707
# Metric: validation.tail.pessimistic.inverse_harmonic_mean_rank = 0.06261982777364399
# Metric: validation.both.pessimistic.inverse_harmonic_mean_rank = 0.03943220957755553
# Metric: validation.head.optimistic.adjusted_geometric_mean_rank_index = 0.6759060392279573
# Metric: validation.tail.optimistic.adjusted_geometric_mean_rank_index = 0.9578966839143959
# Metric: validation.both.optimistic.adjusted_geometric_mean_rank_index = 0.8829510047901319
# Metric: validation.head.realistic.adjusted_geometric_mean_rank_index = 0.6758286964462772
# Metric: validation.tail.realistic.adjusted_geometric_mean_rank_index = 0.9578950766930577
# Metric: validation.both.realistic.adjusted_geometric_mean_rank_index = 0.8829347854836704
# Metric: validation.head.pessimistic.adjusted_geometric_mean_rank_index = 0.6757520504107251
# Metric: validation.tail.pessimistic.adjusted_geometric_mean_rank_index = 0.9578935114067578
# Metric: validation.both.pessimistic.adjusted_geometric_mean_rank_index = 0.8829187545210546
# ...
# Metric: validation.tail.optimistic.hits_at_10 = 0.23727647867950483
# Metric: validation.both.optimistic.hits_at_10 = 0.13651994497936726
# Metric: validation.head.realistic.hits_at_10 = 0.03576341127922971
# Metric: validation.tail.realistic.hits_at_10 = 0.23727647867950483
# Metric: validation.both.realistic.hits_at_10 = 0.13651994497936726
# Metric: validation.head.pessimistic.hits_at_10 = 0.03576341127922971
# Metric: validation.tail.pessimistic.hits_at_10 = 0.23727647867950483
# Metric: validation.both.pessimistic.hits_at_10 = 0.13651994497936726
# Metric: validation.head.optimistic.hits_at_100 = 0.14099037138927098
# Metric: validation.tail.optimistic.hits_at_100 = 0.5742778541953233
# Metric: validation.both.optimistic.hits_at_100 = 0.3576341127922971
# Metric: validation.head.realistic.hits_at_100 = 0.14099037138927098
# Metric: validation.tail.realistic.hits_at_100 = 0.5742778541953233
# Metric: validation.both.realistic.hits_at_100 = 0.3576341127922971
# Metric: validation.head.pessimistic.hits_at_100 = 0.14099037138927098
# Metric: validation.tail.pessimistic.hits_at_100 = 0.5742778541953233
# Metric: validation.both.pessimistic.hits_at_100 = 0.3576341127922971
# Metric: validation.head.optimistic.adjusted_inverse_harmonic_mean_rank = 0.01487564343948875
# Metric: validation.tail.optimistic.adjusted_inverse_harmonic_mean_rank = 0.09640415536485875
# Metric: validation.both.optimistic.adjusted_inverse_harmonic_mean_rank = 0.0556410241254975
# Metric: validation.head.realistic.adjusted_inverse_harmonic_mean_rank = 0.014875221367370852
# Metric: validation.tail.realistic.adjusted_inverse_harmonic_mean_rank = 0.0964041370660468
# Metric: validation.both.realistic.adjusted_inverse_harmonic_mean_rank = 0.05564079737718855
# Metric: validation.head.pessimistic.adjusted_inverse_harmonic_mean_rank = 0.014874813161592426
# Metric: validation.tail.pessimistic.adjusted_inverse_harmonic_mean_rank = 0.09640410855560294
# Metric: validation.both.pessimistic.adjusted_inverse_harmonic_mean_rank = 0.05564058559272975
# Metric: validation.head.optimistic.harmonic_mean_rank = 61.27772846584426
# Metric: validation.tail.optimistic.harmonic_mean_rank = 10.237677840370958
# Metric: validation.both.optimistic.harmonic_mean_rank = 17.544237674799362
# Metric: validation.head.realistic.harmonic_mean_rank = 61.27931104834227
# Metric: validation.tail.realistic.harmonic_mean_rank = 10.237679755566058
# Metric: validation.both.realistic.harmonic_mean_rank = 17.54430736792336
# Metric: validation.head.pessimistic.harmonic_mean_rank = 61.28084171600427
# Metric: validation.tail.pessimistic.harmonic_mean_rank = 10.237682739535106
# Metric: validation.both.pessimistic.harmonic_mean_rank = 17.54437246227407
# Metric: validation.head.optimistic.adjusted_arithmetic_mean_rank_index = 0.4459577743843911
# Metric: validation.tail.optimistic.adjusted_arithmetic_mean_rank_index = 0.8261012367357787
# Metric: validation.both.optimistic.adjusted_arithmetic_mean_rank_index = 0.6397504276743148
# Metric: validation.head.realistic.adjusted_arithmetic_mean_rank_index = 0.4458367287244135
# Metric: validation.tail.realistic.adjusted_arithmetic_mean_rank_index = 0.826083391548509
# Metric: validation.both.realistic.adjusted_arithmetic_mean_rank_index = 0.6396820111124843
# Metric: validation.head.pessimistic.adjusted_arithmetic_mean_rank_index = 0.44571569178141923
# Metric: validation.tail.pessimistic.adjusted_arithmetic_mean_rank_index = 0.8260655586821251
# Metric: validation.both.pessimistic.adjusted_arithmetic_mean_rank_index = 0.6396135676760304
# Metric: validation.head.optimistic.geometric_mean_rank = 726.7729670559715
# Metric: validation.tail.optimistic.geometric_mean_rank = 67.96402443203344
# Metric: validation.both.optimistic.geometric_mean_rank = 222.24854485357926
# Metric: validation.head.realistic.geometric_mean_rank = 726.9472045898438
# Metric: validation.tail.realistic.geometric_mean_rank = 67.96654510498047
# Metric: validation.both.realistic.geometric_mean_rank = 222.2793731689453
# Metric: validation.head.pessimistic.geometric_mean_rank = 727.1204165507206
# Metric: validation.tail.pessimistic.geometric_mean_rank = 67.96903285233252
# Metric: validation.both.pessimistic.geometric_mean_rank = 222.3098546626704
# Metric: validation.head.optimistic.z_arithmetic_mean_rank = 41.57150659094516
# Metric: validation.tail.optimistic.z_arithmetic_mean_rank = 77.14818916832331
# Metric: validation.both.optimistic.z_arithmetic_mean_rank = 84.40238784011511
# Metric: validation.head.realistic.z_arithmetic_mean_rank = 41.56022289831638
# Metric: validation.tail.realistic.z_arithmetic_mean_rank = 77.14652263664172
# Metric: validation.both.realistic.z_arithmetic_mean_rank = 84.39336163093023
# Metric: validation.head.pessimistic.z_arithmetic_mean_rank = 41.54894001827156
# Metric: validation.tail.pessimistic.z_arithmetic_mean_rank = 77.14485725558669
# Metric: validation.both.pessimistic.z_arithmetic_mean_rank = 84.38433187617149
# Metric: validation.head.optimistic.median_absolute_deviation = 1619.74292371737
# Metric: validation.tail.optimistic.median_absolute_deviation = 82.2844231270609
# Metric: validation.both.optimistic.median_absolute_deviation = 467.7609999385174
# Metric: validation.head.realistic.median_absolute_deviation = 1619.74292371737
# Metric: validation.tail.realistic.median_absolute_deviation = 82.2844231270609
# Metric: validation.both.realistic.median_absolute_deviation = 469.9849032662758
# Metric: validation.head.pessimistic.median_absolute_deviation = 1619.74292371737
# Metric: validation.tail.pessimistic.median_absolute_deviation = 82.2844231270609
# Metric: validation.both.pessimistic.median_absolute_deviation = 469.9849032662758
# Metric: validation.head.optimistic.standard_deviation = 1682.7566890861863
# Metric: validation.tail.optimistic.standard_deviation = 1260.0993025500045
# Metric: validation.both.optimistic.standard_deviation = 1601.800501188488
# Metric: validation.head.realistic.standard_deviation = 1683.05615234375
# Metric: validation.tail.realistic.standard_deviation = 1260.1490478515625
# Metric: validation.both.realistic.standard_deviation = 1602.0384521484375
# Metric: validation.head.pessimistic.standard_deviation = 1683.3575011022624
# Metric: validation.tail.pessimistic.standard_deviation = 1260.199397879694
# Metric: validation.both.pessimistic.standard_deviation = 1602.2775541899073
# Metric: validation.head.optimistic.median_rank = 1234.0
# Metric: validation.tail.optimistic.median_rank = 58.5
# Metric: validation.both.optimistic.median_rank = 321.5
# Metric: validation.head.realistic.median_rank = 1234.0
# Metric: validation.tail.realistic.median_rank = 58.5
# Metric: validation.both.realistic.median_rank = 323.0
# Metric: validation.head.pessimistic.median_rank = 1234.0
# Metric: validation.tail.pessimistic.median_rank = 58.5
# Metric: validation.both.pessimistic.median_rank = 323.0
# Metric: validation.head.optimistic.z_inverse_harmonic_mean_rank = 50.059531693649674
# Metric: validation.tail.optimistic.z_inverse_harmonic_mean_rank = 331.46555105334585
# Metric: validation.both.optimistic.z_inverse_harmonic_mean_rank = 267.63140928395245
# Metric: validation.head.realistic.z_inverse_harmonic_mean_rank = 50.05811133609345
# Metric: validation.tail.realistic.z_inverse_harmonic_mean_rank = 331.46548813670324
# Metric: validation.both.realistic.z_inverse_harmonic_mean_rank = 267.6303186323976
# Metric: validation.head.pessimistic.z_inverse_harmonic_mean_rank = 50.0567376415581
# Metric: validation.tail.pessimistic.z_inverse_harmonic_mean_rank = 331.4653901094974
# Metric: validation.both.pessimistic.z_inverse_harmonic_mean_rank = 267.62929995644635
# Metric: validation.head.optimistic.inverse_harmonic_mean_rank = 0.016319142778887314
# Metric: validation.tail.optimistic.inverse_harmonic_mean_rank = 0.09767840086319471
# Metric: validation.both.optimistic.inverse_harmonic_mean_rank = 0.05699877182104102
# Metric: validation.head.realistic.inverse_harmonic_mean_rank = 0.01631872132523024
# Metric: validation.tail.realistic.inverse_harmonic_mean_rank = 0.09767838259018763
# Metric: validation.both.realistic.inverse_harmonic_mean_rank = 0.05699854539873839
# Metric: validation.head.pessimistic.inverse_harmonic_mean_rank = 0.016318313717594343
# Metric: validation.tail.pessimistic.inverse_harmonic_mean_rank = 0.09767835411994903
# Metric: validation.both.pessimistic.inverse_harmonic_mean_rank = 0.05699833391877169
# Metric: validation.head.optimistic.adjusted_geometric_mean_rank_index = 0.6911316546549938
# Metric: validation.tail.optimistic.adjusted_geometric_mean_rank_index = 0.9726490065493627
# Metric: validation.both.optimistic.adjusted_geometric_mean_rank_index = 0.9077493263497074
# Metric: validation.head.realistic.adjusted_geometric_mean_rank_index = 0.6910575041131206
# Metric: validation.tail.realistic.adjusted_geometric_mean_rank_index = 0.9726479769979005
# Metric: validation.both.realistic.adjusted_geometric_mean_rank_index = 0.9077364723313368
# Metric: validation.head.pessimistic.adjusted_geometric_mean_rank_index = 0.6909837900259633
# Metric: validation.tail.pessimistic.adjusted_geometric_mean_rank_index = 0.9726469608946703
# Metric: validation.both.pessimistic.adjusted_geometric_mean_rank_index = 0.9077237629219624
# Metric: validation.head.optimistic.inverse_geometric_mean_rank = 0.0013759455088854264
# Metric: validation.tail.optimistic.inverse_geometric_mean_rank = 0.014713666654628983
# Metric: validation.both.optimistic.inverse_geometric_mean_rank = 0.004499467029846316
# Metric: validation.head.realistic.inverse_geometric_mean_rank = 0.001375615713186562
# Metric: validation.tail.realistic.inverse_geometric_mean_rank = 0.014713120646774769
# Metric: validation.both.realistic.inverse_geometric_mean_rank = 0.004498843103647232
# Metric: validation.head.pessimistic.inverse_geometric_mean_rank = 0.0013752880227786103
# Metric: validation.tail.pessimistic.inverse_geometric_mean_rank = 0.014712582451666923
# Metric: validation.both.pessimistic.inverse_geometric_mean_rank = 0.004498226142594465
# Metric: validation.head.optimistic.adjusted_arithmetic_mean_rank = 0.5541816505430857
# Metric: validation.tail.optimistic.adjusted_arithmetic_mean_rank = 0.17414712183276718
# Metric: validation.both.optimistic.adjusted_arithmetic_mean_rank = 0.36044567055995524
# Metric: validation.head.realistic.adjusted_arithmetic_mean_rank = 0.5543026583591613
# Metric: validation.tail.realistic.adjusted_arithmetic_mean_rank = 0.17416496165507075
# Metric: validation.both.realistic.adjusted_arithmetic_mean_rank = 0.3605140661505345
# Metric: validation.head.pessimistic.adjusted_arithmetic_mean_rank = 0.5544236574609788
# Metric: validation.tail.pessimistic.adjusted_arithmetic_mean_rank = 0.1741827891601926
# Metric: validation.both.pessimistic.adjusted_arithmetic_mean_rank = 0.36058248860749953
# Metric: validation.head.optimistic.inverse_arithmetic_mean_rank = 0.0005641499397244201
# Metric: validation.tail.optimistic.inverse_arithmetic_mean_rank = 0.0017263528836267182
# Metric: validation.both.optimistic.inverse_arithmetic_mean_rank = 0.0008504000652714218
# Metric: validation.head.realistic.inverse_arithmetic_mean_rank = 0.0005640267627313733
# Metric: validation.tail.realistic.inverse_arithmetic_mean_rank = 0.0017261760076507926
# Metric: validation.both.realistic.inverse_arithmetic_mean_rank = 0.0008502387208864093
# Metric: validation.head.pessimistic.inverse_arithmetic_mean_rank = 0.0005639036872669267
# Metric: validation.tail.pessimistic.inverse_arithmetic_mean_rank = 0.0017259993791625342
# Metric: validation.both.pessimistic.inverse_arithmetic_mean_rank = 0.0008500773927062308
# Metric: validation.head.optimistic.arithmetic_mean_rank = 1772.5784044016507
# Metric: validation.tail.optimistic.arithmetic_mean_rank = 579.2558459422283
# Metric: validation.both.optimistic.arithmetic_mean_rank = 1175.9171251719395
# Metric: validation.head.realistic.arithmetic_mean_rank = 1772.9654541015625
# Metric: validation.tail.realistic.arithmetic_mean_rank = 579.315185546875
# Metric: validation.both.realistic.arithmetic_mean_rank = 1176.1402587890625
# Metric: validation.head.pessimistic.arithmetic_mean_rank = 1773.3524759284733
# Metric: validation.tail.pessimistic.arithmetic_mean_rank = 579.374484181568
# Metric: validation.both.pessimistic.arithmetic_mean_rank = 1176.3634800550205
# Metric: validation.head.optimistic.count = 2908.0
# Metric: validation.tail.optimistic.count = 2908.0
# Metric: validation.both.optimistic.count = 5816.0
# Metric: validation.head.realistic.count = 2908.0
# Metric: validation.tail.realistic.count = 2908.0
# Metric: validation.both.realistic.count = 5816.0
# Metric: validation.head.pessimistic.count = 2908.0
# Metric: validation.tail.pessimistic.count = 2908.0
# Metric: validation.both.pessimistic.count = 5816.0
# Metric: validation.head.optimistic.variance = 2831670.074664304
# Metric: validation.tail.optimistic.variance = 1587850.2522870079
# Metric: validation.both.optimistic.variance = 2565764.8456076914
# Metric: validation.head.realistic.variance = 2832678.0
# Metric: validation.tail.realistic.variance = 1587975.625
# Metric: validation.both.realistic.variance = 2566527.25
# Metric: validation.head.pessimistic.variance = 2833692.4765172536
# Metric: validation.tail.pessimistic.variance = 1588102.5224163434
# Metric: validation.both.pessimistic.variance = 2567293.360660791
# Metric: validation.head.optimistic.inverse_median_rank = 0.0008103727714748784
# Metric: validation.tail.optimistic.inverse_median_rank = 0.017094017094017096
# Metric: validation.both.optimistic.inverse_median_rank = 0.003110419906687403
# Metric: validation.head.realistic.inverse_median_rank = 0.0008103727595880628
# Metric: validation.tail.realistic.inverse_median_rank = 0.017094017937779427
# Metric: validation.both.realistic.inverse_median_rank = 0.0030959751456975937
# Metric: validation.head.pessimistic.inverse_median_rank = 0.0008103727714748784
# Metric: validation.tail.pessimistic.inverse_median_rank = 0.017094017094017096
# Metric: validation.both.pessimistic.inverse_median_rank = 0.0030959752321981426
# Metric: validation.head.optimistic.z_geometric_mean_rank = 37.398153635202306
# Metric: validation.tail.optimistic.z_geometric_mean_rank = 52.62605254870048
# Metric: validation.both.optimistic.z_geometric_mean_rank = 69.4534628567478
# Metric: validation.head.realistic.z_geometric_mean_rank = 37.39414123996845
# Metric: validation.tail.realistic.z_geometric_mean_rank = 52.625996843889205
# Metric: validation.both.realistic.z_geometric_mean_rank = 69.45247937368529
# Metric: validation.head.pessimistic.z_geometric_mean_rank = 37.39015246194327
# Metric: validation.tail.pessimistic.z_geometric_mean_rank = 52.625941866706654
# Metric: validation.both.pessimistic.z_geometric_mean_rank = 69.45150695490592
# Metric: validation.head.optimistic.z_hits_at_k = 46.57681631725228
# Metric: validation.tail.optimistic.z_hits_at_k = 328.1537918370496
# Metric: validation.both.optimistic.z_hits_at_k = 262.8140306857136
# Metric: validation.head.realistic.z_hits_at_k = 46.57681631725228
# Metric: validation.tail.realistic.z_hits_at_k = 328.1537918370496
# Metric: validation.both.realistic.z_hits_at_k = 262.8140306857136
# Metric: validation.head.pessimistic.z_hits_at_k = 46.57681631725228
# Metric: validation.tail.pessimistic.z_hits_at_k = 328.1537918370496
# Metric: validation.both.pessimistic.z_hits_at_k = 262.8140306857136
# Metric: validation.head.optimistic.adjusted_hits_at_k = 0.03424741851801801
# Metric: validation.tail.optimistic.adjusted_hits_at_k = 0.23612805570935105
# Metric: validation.both.optimistic.adjusted_hits_at_k = 0.13519108991697373
# Metric: validation.head.realistic.adjusted_hits_at_k = 0.03424741851801801
# Metric: validation.tail.realistic.adjusted_hits_at_k = 0.23612805570935105
# Metric: validation.both.realistic.adjusted_hits_at_k = 0.13519108991697373
# Metric: validation.head.pessimistic.adjusted_hits_at_k = 0.03424741851801801
# Metric: validation.tail.pessimistic.adjusted_hits_at_k = 0.23612805570935105
# Metric: validation.both.pessimistic.adjusted_hits_at_k = 0.13519108991697373
# Step: 7
# Metric: loss = 0.00061731359899402
# Training batches on cuda:0:   0%|          | 0/614 [00:00<?, ?batch/s]
